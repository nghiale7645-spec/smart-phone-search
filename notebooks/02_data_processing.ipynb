# %%
# Đảm bảo lưu đúng vào thư mục data
df.to_csv('data/phone_clean.csv', index=False, encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Đảm bảo lưu đúng vào thư mục data
# ----> 2 df.to_csv('data/phone_clean.csv', index=False, encoding='utf-8-sig')
#
# NameError: name 'df' is not defined
